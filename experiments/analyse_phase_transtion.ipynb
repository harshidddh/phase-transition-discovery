# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
import numpy as np
from ml.pca_analysis import perform_pca
from ml.clustering import perform_kmeans
from ml.visualization import plot_pca_clusters, plot_observability

# %%
# Load the data generated by run_simulation.py
X = np.load("../data/X_configs.npy")
temps = np.load("../data/y_temps.npy")

# %%
# Run the Unsupervised ML Pipeline
X_pca, pca_model = perform_pca(X, n_components=2)
cluster_labels = perform_kmeans(X_pca, n_clusters=3)
# Out:
# c:\Users\harsh\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
# Visualize Symmetry Breaking
plot_pca_clusters(X_pca, cluster_labels, save_path="../figures/pca_clusters.png")

# %%
# Physics Validation: Prove the AI found the Order Parameter
magnetizations = np.abs(np.mean(X, axis=1))
plot_observability(temps, X_pca[:, 0], magnetizations, save_path="../figures/observability.png")

# %%
import numpy as np

temps = np.load("../data/temperatures.npy")
mag = np.load("../data/magnetization.npy")
chi = np.load("../data/susceptibility.npy")

temps, mag, chi
# Out:
# (array([1.        , 1.10344828, 1.20689655, 1.31034483, 1.4137931 ,
#         1.51724138, 1.62068966, 1.72413793, 1.82758621, 1.93103448,
#         2.03448276, 2.13793103, 2.24137931, 2.34482759, 2.44827586,
#         2.55172414, 2.65517241, 2.75862069, 2.86206897, 2.96551724,
#         3.06896552, 3.17241379, 3.27586207, 3.37931034, 3.48275862,
#         3.5862069 , 3.68965517, 3.79310345, 3.89655172, 4.        ]),
#  array([1.        , 1.        , 0.99822222, 0.99466667, 0.248     ,
#         0.98755556, 0.98044444, 0.96444444, 0.95644444, 0.91733333,
#         0.89422222, 0.86844444, 0.40533333, 0.36355556, 0.29777778,
#         0.24533333, 0.35288889, 0.30311111, 0.12444444, 0.22755556,
#         0.16      , 0.21955556, 0.10044444, 0.15288889, 0.13244444,
#         0.18311111, 0.16711111, 0.07022222, 0.13511111, 0.08533333]),
#  array([0.00000000e+00, 0.00000000e+00, 2.35682540e-03, 1.95368421e-02,
#         4.95939295e-01, 1.21858586e-02, 3.24690307e-02, 6.39288889e-02,
#         1.21496017e-01, 2.79965079e-01, 2.17494539e-01, 5.91724731e-01,
#         4.75968821e+00, 1.31800261e+00, 1.53504851e+00, 2.31832793e+00,
#         3.12386494e+00, 3.35781333e+00, 1.42299545e+00, 1.20831835e+00,
#         2.00985568e+00, 4.17426280e+00, 9.95781988e-01, 1.46275737e+00,
#         1.72047525e+00, 3.10964274e+00, 1.74903427e+00, 4.48252121e-01,
#         1.09042281e+00, 4.67600000e-01]))

# %%
import matplotlib.pyplot as plt

plt.plot(temps, mag, marker="o")
plt.xlabel("Temperature")
plt.ylabel("Magnetization")
plt.title("Magnetization vs Temperature")
plt.grid(True)
plt.show()

# %%
plt.plot(temps, chi, marker="o")
plt.xlabel("Temperature")
plt.ylabel("Susceptibility")
plt.title("Susceptibility vs Temperature")
plt.grid(True)
plt.show()
